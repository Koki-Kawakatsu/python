# %%
import pandas as pd

df = pd.read_csv('Ikey240611005A4-wave.csv', header=None)
column_names = ["Column1", "Column2"] 

df.columns = column_names

#print(df.head())
df
# Out:
#     Column1   Column2
# 0       0.0  0.030719
# 1      50.0  0.035327
# 2     100.0  0.030412
# 3     150.0  0.013025
# 4     200.0  0.008982
# ..      ...       ...
# 95   4750.0  0.103576
# 96   4800.0  0.116339
# 97   4850.0  0.135279
# 98   4900.0  0.153301
# 99   4950.0  0.167391
#
# [100 rows x 2 columns]

# %%
df['Column2'] = -df['Column2']

# %%
df.plot(0)
# Out:
# <AxesSubplot: xlabel='Column1'>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = df['Column1']
y = df['Column2']

# Plot the waveforms
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

ax.plot(x, y, color='black', linewidth=2)
ax.axvline(x=2500, color='red', linestyle='--', linewidth=2, label='2500ms')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel('Time (ms)', fontsize=20)
ax.set_ylabel('ΔF/F0 (%)', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=20, width=2)

plt.tight_layout()
plt.show()
